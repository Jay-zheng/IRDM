# %%
import numpy as np
import pandas as pd


import utils

# %%
df_train = pd.read_csv("C:/Users/JayZheng/Documents/Data Science/data mining/home-depot/data/train_clean.csv",encoding="ISO-8859-1")
df_test = pd.read_csv("C:/Users/JayZheng/Documents/Data Science/data mining/home-depot/data/test_clean.csv",encoding="ISO-8859-1")
df_desc = pd.read_csv("C:/Users/JayZheng/Documents/Data Science/data mining/home-depot/data/product_descriptions_clean.csv")
df_attr = pd.read_csv("C:/Users/JayZheng/Documents/Data Science/data mining/home-depot/data/attributes_clean.csv",encoding = "ISO-8859-1")

# %%
df_train = df_train.drop(df_train.columns[0],axis = 1)
df_test = df_test.drop(df_test.columns[0],axis = 1)
numtrain = df_train.shape[0]

# %%
df_attr.head(20)
# Out:
#     product_uid               name  \
# 0      100001.0          bullet 01
# 1      100001.0          bullet 02
# 2      100001.0          bullet 03
# 3      100001.0          bullet 04
# 4      100001.0          bullet 05
# 5      100001.0          bullet 06
# 6      100001.0          bullet 07
# 7      100001.0               gaug
# 8      100001.0             materi
# 9      100001.0     mfg brand name
# 10     100001.0     number of piec
# 11     100001.0  product depth in.
# 12     100001.0     product h8 in.
# 13     100001.0     product w8 lb.
# 14     100001.0  product width in.
# 15     100002.0      applic method
# 16     100002.0  assembl depth in.
# 17     100002.0     assembl h8 in.
# 18     100002.0  assembl width in.
# 19     100002.0          bullet 01
#
#                                                 value
# 0   versatil connector for various 90 deg. connect...
# 1          stronger than angl nail or screw fas10 al1
# 2   help ensur joint are consis10t straight and st...
# 3                    dimens 3 in. x 3 in. x 1-1/2 in.
# 4                             made from 12 gaug steel
# 5                      galvan for extra corros resist
# 6   instal with 10 d common nail or 9 x 1-1/2 in. ...
# 7                                                  12
# 8                                        galvan steel
# 9                                   simpson strong-ti
# 10                                                  1
# 11                                                1.5
# 12                                                  3
# 13                                               0.26
# 14                                                  3
# 15                                 brush roller spray
# 16                                           6.63 in.
# 17                                           7.76 in.
# 18                                           6.63 in.
# 19  reviv wood and composit deck rail porch and bo...

# %%
df_brand = df_attr[df_attr.name == "mfg brand name"][["product_uid", "value"]].rename(columns={"value": "brand"})

# %%
df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)
df_all = pd.merge(df_all, df_brand, how='left', on='product_uid')
df_all = pd.merge(df_all, df_desc, how='left', on='product_uid')

# %%
for var in df_all.keys():
    df_all[var]=df_all[var].fillna("na")

# %%
attr_all = df_attr[df_attr.name != 'mfg brand name'][['product_uid', 'value']].rename(columns={'value': 'attr'})
attr_all['attr'] = attr_all['attr'].apply(lambda x: x if isinstance(x, str) else 'None')
attr_all = attr_all.groupby('product_uid')['attr'].apply(lambda x: ' '.join(x))
attr_all = pd.DataFrame(attr_all)
attr_all = attr_all.reset_index()

# %%
attr_all_title = df_attr[df_attr.name != 'mfg brand name'][['product_uid', 'name']].rename(columns={'name': 'attr_title'})
attr_all_title['attr_title'] = attr_all_title['attr_title'].apply(lambda x: x if isinstance(x, str) else 'None')
attr_all_title = attr_all_title.groupby('product_uid')['attr_title'].apply(lambda x: ' '.join(x))
attr_all_title = pd.DataFrame(attr_all_title)
attr_all_title = attr_all_title.reset_index()

# %%
#attr_all_title

# %%
df_all = pd.merge(df_all, attr_all, how='left', on='product_uid')
df_all = pd.merge(df_all, attr_all_title, how='left', on='product_uid')

# %%
df_all['len_of_query'] = df_all['search_term'].map(lambda x: len(str(x).split())).astype(np.int64)
df_all['len_of_title'] = df_all['product_title'].map(lambda x: len(x.split())).astype(np.int64)
df_all['len_of_description'] = df_all['product_description'].map(lambda x: len(x.split())).astype(np.int64)
df_all['len_of_brand'] = df_all['brand'].map(lambda x: len(str(x).split())).astype(np.int64)
df_all['len_of_attr'] = df_all['attr'].map(lambda x: len(str(x).split())).astype(np.int64)
df_all['len_of_attr_title'] = df_all['attr_title'].map(lambda x: len(str(x).split())).astype(np.int64)

# %%
df_all.head(20)
# Out:
#     id                                      product_title  product_uid  \
# 0    2                      simpson strongti 12 gaug angl       100001
# 1    3                      simpson strongti 12 gaug angl       100001
# 2    9  behr premium textur deckov 1 gal. sc 141 tugbo...       100002
# 3   16  delta vero 1 handl shower faucet trim kit chro...       100005
# 4   17  delta vero 1 handl shower faucet trim kit chro...       100005
# 5   18  whirlpool 19 cu.ft. rang convect microwav stai...       100006
# 6   20  whirlpool 19 cu.ft. rang convect microwav stai...       100006
# 7   21  whirlpool 19 cu.ft. rang convect microwav stai...       100006
# 8   23  lithonia light quantum 2 light black led emerg...       100007
# 9   27            hous fara 34 x 3 x 8 ft. mdf flute case       100009
# 10  34            valley view industri metal stake 4 pack       100010
# 11  35  toro person pace recycl 22 volt. ariabl speed ...       100011
# 12  37  toro person pace recycl 22 volt. ariabl speed ...       100011
# 13  38  toro person pace recycl 22 volt. ariabl speed ...       100011
# 14  48  hampton bay caramel simpl weav bamboo rollup s...       100012
# 15  51  insinker sinktop switch singl outlet insinker ...       100013
# 16  65  sunjoy calai 8 ft. x 5 ft. x 8 ft. steel tile ...       100016
# 17  69  md build product 36 x 36 cloverleaf aluminum s...       100017
# 18  75  md build product 36 x 36 cloverleaf aluminum s...       100017
# 19  81  md build product 36 x 36 cloverleaf aluminum s...       100017
#
#    relevance                      search_term                       brand  \
# 0          3                     angl bracket           simpson strong-ti
# 1        2.5                        l bracket           simpson strong-ti
# 2          3                             deck  behr premium textur deckov
# 3       2.33                 rain shower head                       delta
# 4       2.67                    shower faucet                       delta
# 5          3                      convect otr                   whirlpool
# 6       2.67                   microwav stove                   whirlpool
# 7          3                         microwav                   whirlpool
# 8       2.67                      emerg light              lithonia light
# 9          3                           mdf 34                hous of fara
# 10      2.67                      steel stake        valley view industri
# 11         3        brigg stratton lawn mower                        toro
# 12         3                        gas mower                        toro
# 13         2                      honda mower                        toro
# 14      2.67  hampton bay chestnut pull shade                 hampton bay
# 15      2.67                           dispos                    insinker
# 16         3                     grill gazebo                      sunjoy
# 17         1                       door guard            md build product
# 18      1.67           metal plate cover gfci            md build product
# 19      2.33                     radiat grate            md build product
#
#                                   product_description  \
# 0   angl make joint stronger provid consis10t stra...
# 1   angl make joint stronger provid consis10t stra...
# 2   behr premium textur deckov innov solid color c...
# 3   updat bathroom delta vero singlehandl shower f...
# 4   updat bathroom delta vero singlehandl shower f...
# 5   achiev delici result effortless whirlpool over...
# 6   achiev delici result effortless whirlpool over...
# 7   achiev delici result effortless whirlpool over...
# 8   quantum adjust 2 light led black emerg light u...
# 9   hous fara 34 x 3 x 8 ft. mdf flute case add el...
# 10  valley view industri metal stake 4 pack 9 gal....
# 11  recycl 22 person pace variabl speed selfpropel...
# 12  recycl 22 person pace variabl speed selfpropel...
# 13  recycl 22 person pace variabl speed selfpropel...
# 14  96 wide caramel simpl weav rollup bamboo shade...
# 15  insinker sinktop switch singl outlet insinker ...
# 16  make grill great handsom function grill gazebo...
# 17  md build product 36 x 36 x 150 aluminum clover...
# 18  md build product 36 x 36 x 150 aluminum clover...
# 19  md build product 36 x 36 x 150 aluminum clover...
#
#                                                  attr  \
# 0   versatil connector for various 90 deg. connect...
# 1   versatil connector for various 90 deg. connect...
# 2   brush roller spray 6.63 in. 7.76 in. 6.63 in. ...
# 3   combo tub and shower no includ the trim kit on...
# 4   combo tub and shower no includ the trim kit on...
# 5   over the rang microwav 18.5 in. 17.13 in. 29.9...
# 6   over the rang microwav 18.5 in. 17.13 in. 29.9...
# 7   over the rang microwav 18.5 in. 17.13 in. 29.9...
# 8   ni-cad .built-in led advanc led technolog is d...
# 9   door window made of prime mdf can be paint to ...
# 10  no can be use with all valley view lawn edg an...
# 11  59 in. 44 in. 23 in. 22 in. recycl cut system ...
# 12  59 in. 44 in. 23 in. 22 in. recycl cut system ...
# 13  59 in. 44 in. 23 in. 22 in. recycl cut system ...
# 14  96 no 96 in. w x 72 in. l actual blind width i...
# 15  kit includ satin nickel chrome and white finis...
# 16  8 5 96.45 in. 98.4 in. 60.6 in. vent canopi bu...
# 17  use to repair door or window screen or add sty...
# 18  use to repair door or window screen or add sty...
# 19  use to repair door or window screen or add sty...
#
#                                            attr_title  len_of_query  \
# 0   bullet 01 bullet 02 bullet 03 bullet 04 bullet...             2
# 1   bullet 01 bullet 02 bullet 03 bullet 04 bullet...             2
# 2   applic method assembl depth in. assembl h8 in....             1
# 3   bath faucet type built-in water filter bullet ...             3
# 4   bath faucet type built-in water filter bullet ...             2
# 5   applianc type assembl depth in. assembl h8 in....             2
# 6   applianc type assembl depth in. assembl h8 in....             2
# 7   applianc type assembl depth in. assembl h8 in....             1
# 8   batteri power type batteri size bulb type incl...             2
# 9   applic bullet 01 bullet 02 bullet 03 bullet 04...             2
# 10  attach bullet 01 bullet 02 bullet 03 bullet 04...             2
# 11  assembl depth in. assembl h8 in. assembl width...             4
# 12  assembl depth in. assembl h8 in. assembl width...             2
# 13  assembl depth in. assembl h8 in. assembl width...             2
# 14  actual blind/shad width in. arch bullet 01 bul...             5
# 15  bullet 01 bullet 02 bullet 03 bullet 04 bullet...             1
# 16  approxim depth ft. approxim width ft. assembl ...             2
# 17  bullet 01 bullet 02 bullet 03 bullet 04 bullet...             2
# 18  bullet 01 bullet 02 bullet 03 bullet 04 bullet...             4
# 19  bullet 01 bullet 02 bullet 03 bullet 04 bullet...             2
#
#     len_of_title  len_of_description  len_of_brand  len_of_attr  \
# 0              5                  85             2           68
# 1              5                  85             2           68
# 2             12                 113             4          147
# 3             11                  64             1          105
# 4             11                  64             1          105
# 5             10                 310             1          448
# 6             10                 310             1          448
# 7             10                 310             1          448
# 8             10                  86             2          106
# 9             11                  50             3           47
# 10             7                  71             3           51
# 11            16                 164             1          255
# 12            16                 164             1          255
# 13            16                 164             1          255
# 14            13                 239             2          250
# 15             7                  57             1           62
# 16            15                  87             1           44
# 17            10                  57             3           69
# 18            10                  57             3           69
# 19            10                  57             3           69
#
#     len_of_attr_title
# 0                  31
# 1                  31
# 2                  70
# 3                  65
# 4                  65
# 5                 119
# 6                 119
# 7                 119
# 8                  72
# 9                  50
# 10                 32
# 11                103
# 12                103
# 13                103
# 14                110
# 15                 25
# 16                 39
# 17                 54
# 18                 54
# 19                 54

# %%
df_all['query_in_title'] = df_all.apply(lambda x: utils.counter_appearance(x['search_term'].split(), x['product_title'].split()), axis=1)
df_all['query_in_description'] = df_all.apply(lambda x: utils.counter_appearance(x['search_term'].split(), x['product_description'].split()), axis=1)
df_all['query_in_attr'] = df_all.apply(lambda x: utils.counter_appearance(str(x['search_term']).split(), str(x['attr']).split()), axis=1)
df_all['query_in_attr_title'] = df_all.apply(lambda x: utils.counter_appearance(str(x['search_term']).split(), str(x['attr_title']).split()), axis=1)
#df_all['query_last_word_in_title'] = df_all.apply(lambda x: utils.counter_appearance(x['search_term'].split()[-1], x['product_title'].split()), axis=1)
df_all['query_last_word_in_description'] = df_all.apply(lambda x: utils.counter_appearance(x['search_term'].split()[-1], x['product_description'].split()), axis=1)
df_all['query_last_word_in_attr'] = df_all.apply(lambda x: utils.counter_appearance(str(x['search_term']).split()[-1], str(x['attr']).split()), axis=1)
df_all['query_last_word_in_attr_title'] = df_all.apply(lambda x: utils.counter_appearance(str(x['search_term']).split()[-1], str(x['attr_title']).split()), axis=1)
df_all['word_in_title'] = df_all.apply(lambda x: utils.counter_appear_times(x['search_term'].split(), x['product_title'].split()), axis=1)
df_all['word_in_description'] = df_all.apply(lambda x: utils.counter_appear_times(x['search_term'].split(), x['product_description'].split()), axis=1)
df_all['word_in_attr'] = df_all.apply(lambda x: utils.counter_appear_times(str(x['search_term']).split(), str(x['attr']).split()), axis=1)
df_all['word_in_attr_title'] = df_all.apply(lambda x: utils.counter_appear_times(str(x['search_term']).split(), str(x['attr_title']).split()), axis=1)
df_all['word_in_brand'] = df_all.apply(lambda x: utils.counter_appear_times(x['search_term'].split(), x['brand'].split()), axis=1)

# %%
desc_tf, desc_idf, desc_length, desc_ave_length = utils.tfidf(df_all, 'product_description')
df_all['desc_BM25_score'] = df_all.apply(lambda x: utils.BM25_score(x, desc_tf, desc_idf, desc_length, desc_ave_length), axis=1)
# Out:
# processing  1000 th documents(tf)
# processing  2000 th documents(tf)
# processing  3000 th documents(tf)
# processing  4000 th documents(tf)
# processing  5000 th documents(tf)
# processing  6000 th documents(tf)
# processing  7000 th documents(tf)
# processing  8000 th documents(tf)
# processing  9000 th documents(tf)
# processing  10000 th documents(tf)
# processing  11000 th documents(tf)
# processing  12000 th documents(tf)
# processing  13000 th documents(tf)
# processing  14000 th documents(tf)
# processing  15000 th documents(tf)
# processing  16000 th documents(tf)
# processing  17000 th documents(tf)
# processing  18000 th documents(tf)
# processing  19000 th documents(tf)
# processing  20000 th documents(tf)
# processing  21000 th documents(tf)
# processing  22000 th documents(tf)
# processing  23000 th documents(tf)
# processing  24000 th documents(tf)
# processing  25000 th documents(tf)
# processing  26000 th documents(tf)
# processing  27000 th documents(tf)
# processing  28000 th documents(tf)
# processing  29000 th documents(tf)
# processing  30000 th documents(tf)
# processing  31000 th documents(tf)
# processing  32000 th documents(tf)
# processing  33000 th documents(tf)
# processing  34000 th documents(tf)
# processing  35000 th documents(tf)
# processing  36000 th documents(tf)
# processing  37000 th documents(tf)
# processing  38000 th documents(tf)
# processing  39000 th documents(tf)
# processing  40000 th documents(tf)
# processing  41000 th documents(tf)
# processing  42000 th documents(tf)
# processing  43000 th documents(tf)
# processing  44000 th documents(tf)
# processing  45000 th documents(tf)
# processing  46000 th documents(tf)
# processing  47000 th documents(tf)
# processing  48000 th documents(tf)
# processing  49000 th documents(tf)
# processing  50000 th documents(tf)
# processing  51000 th documents(tf)
# processing  52000 th documents(tf)
# processing  53000 th documents(tf)
# processing  54000 th documents(tf)
# processing  55000 th documents(tf)
# processing  56000 th documents(tf)
# processing  57000 th documents(tf)
# processing  58000 th documents(tf)
# processing  59000 th documents(tf)
# processing  60000 th documents(tf)
# processing  61000 th documents(tf)
# processing  62000 th documents(tf)
# processing  63000 th documents(tf)
# processing  64000 th documents(tf)
# processing  65000 th documents(tf)
# processing  66000 th documents(tf)
# processing  67000 th documents(tf)
# processing  68000 th documents(tf)
# processing  69000 th documents(tf)
# processing  70000 th documents(tf)
# processing  71000 th documents(tf)
# processing  72000 th documents(tf)
# processing  73000 th documents(tf)
# processing  74000 th documents(tf)
# processing  75000 th documents(tf)
# processing  76000 th documents(tf)
# processing  77000 th documents(tf)
# processing  78000 th documents(tf)
# processing  79000 th documents(tf)
# processing  80000 th documents(tf)
# processing  81000 th documents(tf)
# processing  82000 th documents(tf)
# processing  83000 th documents(tf)
# processing  84000 th documents(tf)
# processing  85000 th documents(tf)
# processing  86000 th documents(tf)
# processing  87000 th documents(tf)
# processing  88000 th documents(tf)
# processing  89000 th documents(tf)
# processing  90000 th documents(tf)
# processing  91000 th documents(tf)
# processing  92000 th documents(tf)
# processing  93000 th documents(tf)
# processing  94000 th documents(tf)
# processing  95000 th documents(tf)
# processing  96000 th documents(tf)
# processing  97000 th documents(tf)
# processing  98000 th documents(tf)
# processing  99000 th documents(tf)
# processing  100000 th documents(tf)
# processing  101000 th documents(tf)
# processing  102000 th documents(tf)
# processing  103000 th documents(tf)
# processing  104000 th documents(tf)
# processing  105000 th documents(tf)
# processing  106000 th documents(tf)
# processing  107000 th documents(tf)
# processing  108000 th documents(tf)
# processing  109000 th documents(tf)
# processing  110000 th documents(tf)
# processing  111000 th documents(tf)
# processing  112000 th documents(tf)
# processing  113000 th documents(tf)
# processing  114000 th documents(tf)
# processing  115000 th documents(tf)
# processing  116000 th documents(tf)
# processing  117000 th documents(tf)
# processing  118000 th documents(tf)
# processing  119000 th documents(tf)
# processing  120000 th documents(tf)
# processing  121000 th documents(tf)
# processing  122000 th documents(tf)
# processing  123000 th documents(tf)
# processing  124000 th documents(tf)
# processing  125000 th documents(tf)
# processing  126000 th documents(tf)
# processing  127000 th documents(tf)
# processing  128000 th documents(tf)
# processing  129000 th documents(tf)
# processing  130000 th documents(tf)
# processing  131000 th documents(tf)
# processing  132000 th documents(tf)
# processing  133000 th documents(tf)
# processing  134000 th documents(tf)
# processing  135000 th documents(tf)
# processing  136000 th documents(tf)
# processing  137000 th documents(tf)
# processing  138000 th documents(tf)
# processing  139000 th documents(tf)
# processing  140000 th documents(tf)
# processing  141000 th documents(tf)
# processing  142000 th documents(tf)
# processing  143000 th documents(tf)
# processing  144000 th documents(tf)
# processing  145000 th documents(tf)
# processing  146000 th documents(tf)
# processing  147000 th documents(tf)
# processing  148000 th documents(tf)
# processing  149000 th documents(tf)
# processing  150000 th documents(tf)
# processing  151000 th documents(tf)
# processing  152000 th documents(tf)
# processing  153000 th documents(tf)
# processing  154000 th documents(tf)
# processing  155000 th documents(tf)
# processing  156000 th documents(tf)
# processing  157000 th documents(tf)
# processing  158000 th documents(tf)
# processing  159000 th documents(tf)
# processing  160000 th documents(tf)
# processing  161000 th documents(tf)
# processing  162000 th documents(tf)
# processing  163000 th documents(tf)
# processing  164000 th documents(tf)
# processing  165000 th documents(tf)
# processing  166000 th documents(tf)
# processing  167000 th documents(tf)
# processing  168000 th documents(tf)
# processing  169000 th documents(tf)
# processing  170000 th documents(tf)
# processing  171000 th documents(tf)
# processing  172000 th documents(tf)
# processing  173000 th documents(tf)
# processing  174000 th documents(tf)
# processing  175000 th documents(tf)
# processing  176000 th documents(tf)
# processing  177000 th documents(tf)
# processing  178000 th documents(tf)
# processing  179000 th documents(tf)
# processing  180000 th documents(tf)
# processing  181000 th documents(tf)
# processing  182000 th documents(tf)
# processing  183000 th documents(tf)
# processing  184000 th documents(tf)
# processing  185000 th documents(tf)
# processing  186000 th documents(tf)
# processing  187000 th documents(tf)
# processing  188000 th documents(tf)
# processing  189000 th documents(tf)
# processing  190000 th documents(tf)
# processing  191000 th documents(tf)
# processing  192000 th documents(tf)
# processing  193000 th documents(tf)
# processing  194000 th documents(tf)
# processing  195000 th documents(tf)
# processing  196000 th documents(tf)
# processing  197000 th documents(tf)
# processing  198000 th documents(tf)
# processing  199000 th documents(tf)
# processing  200000 th documents(tf)
# processing  201000 th documents(tf)
# processing  202000 th documents(tf)
# processing  203000 th documents(tf)
# processing  204000 th documents(tf)
# processing  205000 th documents(tf)
# processing  206000 th documents(tf)
# processing  207000 th documents(tf)
# processing  208000 th documents(tf)
# processing  209000 th documents(tf)
# processing  210000 th documents(tf)
# processing  211000 th documents(tf)
# processing  212000 th documents(tf)
# processing  213000 th documents(tf)
# processing  214000 th documents(tf)
# processing  215000 th documents(tf)
# processing  216000 th documents(tf)
# processing  217000 th documents(tf)
# processing  218000 th documents(tf)
# processing  219000 th documents(tf)
# processing  220000 th documents(tf)
# processing  221000 th documents(tf)
# processing  222000 th documents(tf)
# processing  223000 th documents(tf)
# processing  224000 th documents(tf)
# processing  225000 th documents(tf)
# processing  226000 th documents(tf)
# processing  227000 th documents(tf)
# processing  228000 th documents(tf)
# processing  229000 th documents(tf)
# processing  230000 th documents(tf)
# processing  231000 th documents(tf)
# processing  232000 th documents(tf)
# processing  233000 th documents(tf)
# processing  234000 th documents(tf)
# processing  235000 th documents(tf)
# processing  236000 th documents(tf)
# processing  237000 th documents(tf)
# processing  238000 th documents(tf)
# processing  239000 th documents(tf)
# processing  240000 th documents(tf)
# processing  1000 th word(idf)
# processing  2000 th word(idf)
# processing  3000 th word(idf)
# processing  4000 th word(idf)
# processing  5000 th word(idf)
# processing  6000 th word(idf)
# processing  7000 th word(idf)
# processing  8000 th word(idf)
# processing  9000 th word(idf)
# processing  10000 th word(idf)
# processing  11000 th word(idf)
# processing  12000 th word(idf)
# processing  13000 th word(idf)
# processing  14000 th word(idf)
# processing  15000 th word(idf)
# processing  16000 th word(idf)
# processing  17000 th word(idf)
# processing  18000 th word(idf)
# processing  19000 th word(idf)
# processing  20000 th word(idf)
# processing  21000 th word(idf)
# processing  22000 th word(idf)
# processing  23000 th word(idf)
# processing  24000 th word(idf)
# processing  25000 th word(idf)
# processing  26000 th word(idf)
# processing  27000 th word(idf)
# processing  28000 th word(idf)
# processing  29000 th word(idf)
# processing  30000 th word(idf)
# processing  31000 th word(idf)
# processing  32000 th word(idf)
# processing  33000 th word(idf)
# processing  34000 th word(idf)
# processing  35000 th word(idf)
# processing  36000 th word(idf)
# processing  37000 th word(idf)
# processing  38000 th word(idf)
# processing  39000 th word(idf)
# processing  40000 th word(idf)
# processing  41000 th word(idf)
# processing  42000 th word(idf)
# processing  43000 th word(idf)
# processing  44000 th word(idf)
# processing  45000 th word(idf)
# processing  46000 th word(idf)
# processing  47000 th word(idf)
# processing  48000 th word(idf)
# processing  49000 th word(idf)
# processing  50000 th word(idf)
# processing  51000 th word(idf)
# processing  52000 th word(idf)
# processing  53000 th word(idf)
# processing  54000 th word(idf)
# processing  55000 th word(idf)
# processing  56000 th word(idf)
# processing  57000 th word(idf)
# processing  58000 th word(idf)
# processing  59000 th word(idf)
# processing  60000 th word(idf)
# processing  61000 th word(idf)
# processing  62000 th word(idf)
# processing  63000 th word(idf)
# processing  64000 th word(idf)
# processing  65000 th word(idf)
# processing  66000 th word(idf)
# processing  67000 th word(idf)
# processing  68000 th word(idf)
# processing  69000 th word(idf)
# processing  70000 th word(idf)
# processing  71000 th word(idf)
# processing  72000 th word(idf)
# processing  73000 th word(idf)
# processing  74000 th word(idf)
# processing  75000 th word(idf)
# processing  76000 th word(idf)
# processing  77000 th word(idf)
# processing  78000 th word(idf)
# processing  79000 th word(idf)
# processing  80000 th word(idf)
# processing  81000 th word(idf)
# processing  82000 th word(idf)
# processing  83000 th word(idf)
# processing  84000 th word(idf)
# processing  85000 th word(idf)
# processing  86000 th word(idf)
# processing  87000 th word(idf)
# processing  88000 th word(idf)
# processing  89000 th word(idf)
# processing  90000 th word(idf)
# processing  91000 th word(idf)
# processing  92000 th word(idf)
# processing  93000 th word(idf)
# processing  94000 th word(idf)
# processing  95000 th word(idf)
# processing  96000 th word(idf)
# processing  97000 th word(idf)
# processing  98000 th word(idf)
# processing  99000 th word(idf)
# processing  100000 th word(idf)
# processing  101000 th word(idf)
# processing  102000 th word(idf)
# processing  103000 th word(idf)
# processing  104000 th word(idf)
# processing  105000 th word(idf)
# processing  106000 th word(idf)
# processing  107000 th word(idf)
# processing  108000 th word(idf)
# processing  109000 th word(idf)
# processing  110000 th word(idf)
# processing  111000 th word(idf)
# processing  112000 th word(idf)
# processing  113000 th word(idf)
# processing  114000 th word(idf)
# processing  115000 th word(idf)
# processing  116000 th word(idf)
# processing  117000 th word(idf)
# processing  118000 th word(idf)
# processing  119000 th word(idf)
# processing  120000 th word(idf)
# processing  121000 th word(idf)
# processing  122000 th word(idf)
# processing  123000 th word(idf)
# processing  124000 th word(idf)
# processing  125000 th word(idf)
# processing  126000 th word(idf)
# processing  127000 th word(idf)
# processing  128000 th word(idf)
# processing  129000 th word(idf)
# processing  130000 th word(idf)
# processing  131000 th word(idf)
# processing  132000 th word(idf)
# processing  133000 th word(idf)
# processing  134000 th word(idf)
# processing  135000 th word(idf)
# processing  136000 th word(idf)
# processing  137000 th word(idf)
# processing  138000 th word(idf)
# processing  139000 th word(idf)
# processing  140000 th word(idf)
# processing  141000 th word(idf)
# processing  142000 th word(idf)
# processing  143000 th word(idf)
# processing  144000 th word(idf)
# processing  145000 th word(idf)
# processing  146000 th word(idf)
# processing  147000 th word(idf)
# processing  148000 th word(idf)
# processing  149000 th word(idf)
# processing  150000 th word(idf)
# processing  151000 th word(idf)
# processing  152000 th word(idf)
# processing  153000 th word(idf)
# processing  154000 th word(idf)
# processing  155000 th word(idf)
# processing  156000 th word(idf)
# processing  157000 th word(idf)
# processing  158000 th word(idf)
# processing  159000 th word(idf)
# processing  160000 th word(idf)
# processing  161000 th word(idf)
# processing  162000 th word(idf)
# processing  163000 th word(idf)
# processing  164000 th word(idf)
# processing  165000 th word(idf)
# processing  166000 th word(idf)
# processing  167000 th word(idf)
# processing  168000 th word(idf)
# processing  169000 th word(idf)
# processing  170000 th word(idf)
# processing  171000 th word(idf)
# processing  172000 th word(idf)
# processing  173000 th word(idf)
# processing  174000 th word(idf)
# processing  175000 th word(idf)
# processing  176000 th word(idf)
# processing  177000 th word(idf)
# processing  178000 th word(idf)
# processing  179000 th word(idf)
# processing  180000 th word(idf)
# processing  181000 th word(idf)
# processing  182000 th word(idf)
# processing  183000 th word(idf)
# processing  184000 th word(idf)
# processing  185000 th word(idf)
# processing  186000 th word(idf)
# processing  187000 th word(idf)
# processing  188000 th word(idf)
# processing  189000 th word(idf)
# processing  190000 th word(idf)
# processing  191000 th word(idf)
# processing  192000 th word(idf)
# processing  193000 th word(idf)
# processing  194000 th word(idf)
# processing  195000 th word(idf)
# processing  196000 th word(idf)
# processing  197000 th word(idf)
# processing  198000 th word(idf)
# processing  199000 th word(idf)
# processing  200000 th word(idf)
# processing  201000 th word(idf)
# processing  202000 th word(idf)
# processing  203000 th word(idf)
# processing  204000 th word(idf)
# processing  205000 th word(idf)
# processing  206000 th word(idf)
# processing  207000 th word(idf)
# processing  208000 th word(idf)
# processing  209000 th word(idf)
# processing  210000 th word(idf)
# processing  211000 th word(idf)
# processing  212000 th word(idf)
# processing  213000 th word(idf)
# processing  214000 th word(idf)
# processing  215000 th word(idf)
# processing  216000 th word(idf)
# processing  217000 th word(idf)
# processing  218000 th word(idf)
# processing  219000 th word(idf)
# processing  220000 th word(idf)
# processing  221000 th word(idf)
# processing  222000 th word(idf)
# processing  223000 th word(idf)
# processing  224000 th word(idf)
# processing  225000 th word(idf)
# processing  226000 th word(idf)
# processing  227000 th word(idf)
# processing  228000 th word(idf)
# processing  229000 th word(idf)
# processing  230000 th word(idf)
# processing  231000 th word(idf)
# processing  232000 th word(idf)
# processing  233000 th word(idf)
# processing  234000 th word(idf)
# processing  235000 th word(idf)
# processing  236000 th word(idf)
# processing  237000 th word(idf)
# processing  238000 th word(idf)
# processing  239000 th word(idf)
# processing  240000 th word(idf)
# processing  241000 th word(idf)
# processing  242000 th word(idf)
# processing  243000 th word(idf)
# processing  244000 th word(idf)
# processing  245000 th word(idf)
# processing  246000 th word(idf)
# processing  247000 th word(idf)
# processing  248000 th word(idf)
# processing  249000 th word(idf)
# processing  250000 th word(idf)
# processing  251000 th word(idf)
# processing  252000 th word(idf)
# processing  253000 th word(idf)
# processing  254000 th word(idf)
# processing  255000 th word(idf)
# processing  256000 th word(idf)
# processing  257000 th word(idf)
# processing  258000 th word(idf)
# processing  259000 th word(idf)
# processing  260000 th word(idf)
# processing  261000 th word(idf)
# processing  262000 th word(idf)
# processing  263000 th word(idf)
# processing  264000 th word(idf)
# processing  265000 th word(idf)
# processing  266000 th word(idf)
# processing  267000 th word(idf)
# processing  268000 th word(idf)
# processing  269000 th word(idf)
# processing  270000 th word(idf)
# processing  271000 th word(idf)
# processing  272000 th word(idf)
# processing  273000 th word(idf)
# processing  274000 th word(idf)
# processing  275000 th word(idf)
# processing  276000 th word(idf)
# processing  277000 th word(idf)
# processing  278000 th word(idf)

# %%
attr_tf, attr_idf, attr_length, attr_ave_length = utils.tfidf(df_all, 'attr')
df_all['attr_BM25_score'] = df_all.apply(lambda x: utils.BM25_score(x, attr_tf, attr_idf, attr_length, attr_ave_length), axis=1)
# Out:
# processing  1000 th documents(tf)
# processing  2000 th documents(tf)
# processing  3000 th documents(tf)
# processing  4000 th documents(tf)
# processing  5000 th documents(tf)
# processing  6000 th documents(tf)
# processing  7000 th documents(tf)
# processing  8000 th documents(tf)
# processing  9000 th documents(tf)
# processing  10000 th documents(tf)
# processing  11000 th documents(tf)
# processing  12000 th documents(tf)
# processing  13000 th documents(tf)
# processing  14000 th documents(tf)
# processing  15000 th documents(tf)
# processing  16000 th documents(tf)
# processing  17000 th documents(tf)
# processing  18000 th documents(tf)
# processing  19000 th documents(tf)
# processing  20000 th documents(tf)
# processing  21000 th documents(tf)
# processing  22000 th documents(tf)
# processing  23000 th documents(tf)
# processing  24000 th documents(tf)
# processing  25000 th documents(tf)
# processing  26000 th documents(tf)
# processing  27000 th documents(tf)
# processing  28000 th documents(tf)
# processing  29000 th documents(tf)
# processing  30000 th documents(tf)
# processing  31000 th documents(tf)
# processing  32000 th documents(tf)
# processing  33000 th documents(tf)
# processing  34000 th documents(tf)
# processing  35000 th documents(tf)
# processing  36000 th documents(tf)
# processing  37000 th documents(tf)
# processing  38000 th documents(tf)
# processing  39000 th documents(tf)
# processing  40000 th documents(tf)
# processing  41000 th documents(tf)
# processing  42000 th documents(tf)
# processing  43000 th documents(tf)
# processing  44000 th documents(tf)
# processing  45000 th documents(tf)
# processing  46000 th documents(tf)
# processing  47000 th documents(tf)
# processing  48000 th documents(tf)
# processing  49000 th documents(tf)
# processing  50000 th documents(tf)
# processing  51000 th documents(tf)
# processing  52000 th documents(tf)
# processing  53000 th documents(tf)
# processing  54000 th documents(tf)
# processing  55000 th documents(tf)
# processing  56000 th documents(tf)
# processing  57000 th documents(tf)
# processing  58000 th documents(tf)
# processing  59000 th documents(tf)
# processing  60000 th documents(tf)
# processing  61000 th documents(tf)
# processing  62000 th documents(tf)
# processing  63000 th documents(tf)
# processing  64000 th documents(tf)
# processing  65000 th documents(tf)
# processing  66000 th documents(tf)
# processing  67000 th documents(tf)
# processing  68000 th documents(tf)
# processing  69000 th documents(tf)
# processing  70000 th documents(tf)
# processing  71000 th documents(tf)
# processing  72000 th documents(tf)
# processing  73000 th documents(tf)
# processing  74000 th documents(tf)
# processing  75000 th documents(tf)
# processing  76000 th documents(tf)
# processing  77000 th documents(tf)
# processing  78000 th documents(tf)
# processing  79000 th documents(tf)
# processing  80000 th documents(tf)
# processing  81000 th documents(tf)
# processing  82000 th documents(tf)
# processing  83000 th documents(tf)
# processing  84000 th documents(tf)
# processing  85000 th documents(tf)
# processing  86000 th documents(tf)
# processing  87000 th documents(tf)
# processing  88000 th documents(tf)
# processing  89000 th documents(tf)
# processing  90000 th documents(tf)
# processing  91000 th documents(tf)
# processing  92000 th documents(tf)
# processing  93000 th documents(tf)
# processing  94000 th documents(tf)
# processing  95000 th documents(tf)
# processing  96000 th documents(tf)
# processing  97000 th documents(tf)
# processing  98000 th documents(tf)
# processing  99000 th documents(tf)
# processing  100000 th documents(tf)
# processing  101000 th documents(tf)
# processing  102000 th documents(tf)
# processing  103000 th documents(tf)
# processing  104000 th documents(tf)
# processing  105000 th documents(tf)
# processing  106000 th documents(tf)
# processing  107000 th documents(tf)
# processing  108000 th documents(tf)
# processing  109000 th documents(tf)
# processing  110000 th documents(tf)
# processing  111000 th documents(tf)
# processing  112000 th documents(tf)
# processing  113000 th documents(tf)
# processing  114000 th documents(tf)
# processing  115000 th documents(tf)
# processing  116000 th documents(tf)
# processing  117000 th documents(tf)
# processing  118000 th documents(tf)
# processing  119000 th documents(tf)
# processing  120000 th documents(tf)
# processing  121000 th documents(tf)
# processing  122000 th documents(tf)
# processing  123000 th documents(tf)
# processing  124000 th documents(tf)
# processing  125000 th documents(tf)
# processing  126000 th documents(tf)
# processing  127000 th documents(tf)
# processing  128000 th documents(tf)
# processing  129000 th documents(tf)
# processing  130000 th documents(tf)
# processing  131000 th documents(tf)
# processing  132000 th documents(tf)
# processing  133000 th documents(tf)
# processing  134000 th documents(tf)
# processing  135000 th documents(tf)
# processing  136000 th documents(tf)
# processing  137000 th documents(tf)
# processing  138000 th documents(tf)
# processing  139000 th documents(tf)
# processing  140000 th documents(tf)
# processing  141000 th documents(tf)
# processing  142000 th documents(tf)
# processing  143000 th documents(tf)
# processing  144000 th documents(tf)
# processing  145000 th documents(tf)
# processing  146000 th documents(tf)
# processing  147000 th documents(tf)
# processing  148000 th documents(tf)
# processing  149000 th documents(tf)
# processing  150000 th documents(tf)
# processing  151000 th documents(tf)
# processing  152000 th documents(tf)
# processing  153000 th documents(tf)
# processing  154000 th documents(tf)
# processing  155000 th documents(tf)
# processing  156000 th documents(tf)
# processing  157000 th documents(tf)
# processing  158000 th documents(tf)
# processing  159000 th documents(tf)
# processing  160000 th documents(tf)
# processing  161000 th documents(tf)
# processing  162000 th documents(tf)
# processing  163000 th documents(tf)
# processing  164000 th documents(tf)
# processing  165000 th documents(tf)
# processing  166000 th documents(tf)
# processing  167000 th documents(tf)
# processing  168000 th documents(tf)
# processing  169000 th documents(tf)
# processing  170000 th documents(tf)
# processing  171000 th documents(tf)
# processing  172000 th documents(tf)
# processing  173000 th documents(tf)
# processing  174000 th documents(tf)
# processing  175000 th documents(tf)
# processing  176000 th documents(tf)
# processing  177000 th documents(tf)
# processing  178000 th documents(tf)
# processing  179000 th documents(tf)
# processing  180000 th documents(tf)
# processing  181000 th documents(tf)
# processing  182000 th documents(tf)
# processing  183000 th documents(tf)
# processing  184000 th documents(tf)
# processing  185000 th documents(tf)
# processing  186000 th documents(tf)
# processing  187000 th documents(tf)
# processing  188000 th documents(tf)
# processing  189000 th documents(tf)
# processing  190000 th documents(tf)
# processing  191000 th documents(tf)
# processing  192000 th documents(tf)
# processing  193000 th documents(tf)
# processing  194000 th documents(tf)
# processing  195000 th documents(tf)
# processing  196000 th documents(tf)
# processing  197000 th documents(tf)
# processing  198000 th documents(tf)
# processing  199000 th documents(tf)
# processing  200000 th documents(tf)
# processing  201000 th documents(tf)
# processing  202000 th documents(tf)
# processing  203000 th documents(tf)
# processing  204000 th documents(tf)
# processing  205000 th documents(tf)
# processing  206000 th documents(tf)
# processing  207000 th documents(tf)
# processing  208000 th documents(tf)
# processing  209000 th documents(tf)
# processing  210000 th documents(tf)
# processing  211000 th documents(tf)
# processing  212000 th documents(tf)
# processing  213000 th documents(tf)
# processing  214000 th documents(tf)
# processing  215000 th documents(tf)
# processing  216000 th documents(tf)
# processing  217000 th documents(tf)
# processing  218000 th documents(tf)
# processing  219000 th documents(tf)
# processing  220000 th documents(tf)
# processing  221000 th documents(tf)
# processing  222000 th documents(tf)
# processing  223000 th documents(tf)
# processing  224000 th documents(tf)
# processing  225000 th documents(tf)
# processing  226000 th documents(tf)
# processing  227000 th documents(tf)
# processing  228000 th documents(tf)
# processing  229000 th documents(tf)
# processing  230000 th documents(tf)
# processing  231000 th documents(tf)
# processing  232000 th documents(tf)
# processing  233000 th documents(tf)
# processing  234000 th documents(tf)
# processing  235000 th documents(tf)
# processing  236000 th documents(tf)
# processing  237000 th documents(tf)
# processing  238000 th documents(tf)
# processing  239000 th documents(tf)
# processing  240000 th documents(tf)
# processing  1000 th word(idf)
# processing  2000 th word(idf)
# processing  3000 th word(idf)
# processing  4000 th word(idf)
# processing  5000 th word(idf)
# processing  6000 th word(idf)
# processing  7000 th word(idf)
# processing  8000 th word(idf)
# processing  9000 th word(idf)
# processing  10000 th word(idf)
# processing  11000 th word(idf)
# processing  12000 th word(idf)
# processing  13000 th word(idf)
# processing  14000 th word(idf)
# processing  15000 th word(idf)
# processing  16000 th word(idf)
# processing  17000 th word(idf)
# processing  18000 th word(idf)
# processing  19000 th word(idf)
# processing  20000 th word(idf)
# processing  21000 th word(idf)
# processing  22000 th word(idf)
# processing  23000 th word(idf)
# processing  24000 th word(idf)
# processing  25000 th word(idf)
# processing  26000 th word(idf)
# processing  27000 th word(idf)
# processing  28000 th word(idf)
# processing  29000 th word(idf)
# processing  30000 th word(idf)
# processing  31000 th word(idf)
# processing  32000 th word(idf)
# processing  33000 th word(idf)
# processing  34000 th word(idf)
# processing  35000 th word(idf)
# processing  36000 th word(idf)
# processing  37000 th word(idf)
# processing  38000 th word(idf)
# processing  39000 th word(idf)
# processing  40000 th word(idf)
# processing  41000 th word(idf)
# processing  42000 th word(idf)
# processing  43000 th word(idf)
# processing  44000 th word(idf)
# processing  45000 th word(idf)
# processing  46000 th word(idf)
# processing  47000 th word(idf)
# processing  48000 th word(idf)
# processing  49000 th word(idf)
# processing  50000 th word(idf)
# processing  51000 th word(idf)
# processing  52000 th word(idf)
# processing  53000 th word(idf)
# processing  54000 th word(idf)
# processing  55000 th word(idf)
# processing  56000 th word(idf)
# processing  57000 th word(idf)
# processing  58000 th word(idf)
# processing  59000 th word(idf)

# %%
title_tf, title_idf, title_length, title_ave_length = utils.tfidf(df_all, 'product_title')
df_all['title_BM25_score'] = df_all.apply(lambda x: utils.BM25_score(x, title_tf, title_idf, title_length, title_ave_length), axis=1)
# Out:
# processing  1000 th documents(tf)
# processing  2000 th documents(tf)
# processing  3000 th documents(tf)
# processing  4000 th documents(tf)
# processing  5000 th documents(tf)
# processing  6000 th documents(tf)
# processing  7000 th documents(tf)
# processing  8000 th documents(tf)
# processing  9000 th documents(tf)
# processing  10000 th documents(tf)
# processing  11000 th documents(tf)
# processing  12000 th documents(tf)
# processing  13000 th documents(tf)
# processing  14000 th documents(tf)
# processing  15000 th documents(tf)
# processing  16000 th documents(tf)
# processing  17000 th documents(tf)
# processing  18000 th documents(tf)
# processing  19000 th documents(tf)
# processing  20000 th documents(tf)
# processing  21000 th documents(tf)
# processing  22000 th documents(tf)
# processing  23000 th documents(tf)
# processing  24000 th documents(tf)
# processing  25000 th documents(tf)
# processing  26000 th documents(tf)
# processing  27000 th documents(tf)
# processing  28000 th documents(tf)
# processing  29000 th documents(tf)
# processing  30000 th documents(tf)
# processing  31000 th documents(tf)
# processing  32000 th documents(tf)
# processing  33000 th documents(tf)
# processing  34000 th documents(tf)
# processing  35000 th documents(tf)
# processing  36000 th documents(tf)
# processing  37000 th documents(tf)
# processing  38000 th documents(tf)
# processing  39000 th documents(tf)
# processing  40000 th documents(tf)
# processing  41000 th documents(tf)
# processing  42000 th documents(tf)
# processing  43000 th documents(tf)
# processing  44000 th documents(tf)
# processing  45000 th documents(tf)
# processing  46000 th documents(tf)
# processing  47000 th documents(tf)
# processing  48000 th documents(tf)
# processing  49000 th documents(tf)
# processing  50000 th documents(tf)
# processing  51000 th documents(tf)
# processing  52000 th documents(tf)
# processing  53000 th documents(tf)
# processing  54000 th documents(tf)
# processing  55000 th documents(tf)
# processing  56000 th documents(tf)
# processing  57000 th documents(tf)
# processing  58000 th documents(tf)
# processing  59000 th documents(tf)
# processing  60000 th documents(tf)
# processing  61000 th documents(tf)
# processing  62000 th documents(tf)
# processing  63000 th documents(tf)
# processing  64000 th documents(tf)
# processing  65000 th documents(tf)
# processing  66000 th documents(tf)
# processing  67000 th documents(tf)
# processing  68000 th documents(tf)
# processing  69000 th documents(tf)
# processing  70000 th documents(tf)
# processing  71000 th documents(tf)
# processing  72000 th documents(tf)
# processing  73000 th documents(tf)
# processing  74000 th documents(tf)
# processing  75000 th documents(tf)
# processing  76000 th documents(tf)
# processing  77000 th documents(tf)
# processing  78000 th documents(tf)
# processing  79000 th documents(tf)
# processing  80000 th documents(tf)
# processing  81000 th documents(tf)
# processing  82000 th documents(tf)
# processing  83000 th documents(tf)
# processing  84000 th documents(tf)
# processing  85000 th documents(tf)
# processing  86000 th documents(tf)
# processing  87000 th documents(tf)
# processing  88000 th documents(tf)
# processing  89000 th documents(tf)
# processing  90000 th documents(tf)
# processing  91000 th documents(tf)
# processing  92000 th documents(tf)
# processing  93000 th documents(tf)
# processing  94000 th documents(tf)
# processing  95000 th documents(tf)
# processing  96000 th documents(tf)
# processing  97000 th documents(tf)
# processing  98000 th documents(tf)
# processing  99000 th documents(tf)
# processing  100000 th documents(tf)
# processing  101000 th documents(tf)
# processing  102000 th documents(tf)
# processing  103000 th documents(tf)
# processing  104000 th documents(tf)
# processing  105000 th documents(tf)
# processing  106000 th documents(tf)
# processing  107000 th documents(tf)
# processing  108000 th documents(tf)
# processing  109000 th documents(tf)
# processing  110000 th documents(tf)
# processing  111000 th documents(tf)
# processing  112000 th documents(tf)
# processing  113000 th documents(tf)
# processing  114000 th documents(tf)
# processing  115000 th documents(tf)
# processing  116000 th documents(tf)
# processing  117000 th documents(tf)
# processing  118000 th documents(tf)
# processing  119000 th documents(tf)
# processing  120000 th documents(tf)
# processing  121000 th documents(tf)
# processing  122000 th documents(tf)
# processing  123000 th documents(tf)
# processing  124000 th documents(tf)
# processing  125000 th documents(tf)
# processing  126000 th documents(tf)
# processing  127000 th documents(tf)
# processing  128000 th documents(tf)
# processing  129000 th documents(tf)
# processing  130000 th documents(tf)
# processing  131000 th documents(tf)
# processing  132000 th documents(tf)
# processing  133000 th documents(tf)
# processing  134000 th documents(tf)
# processing  135000 th documents(tf)
# processing  136000 th documents(tf)
# processing  137000 th documents(tf)
# processing  138000 th documents(tf)
# processing  139000 th documents(tf)
# processing  140000 th documents(tf)
# processing  141000 th documents(tf)
# processing  142000 th documents(tf)
# processing  143000 th documents(tf)
# processing  144000 th documents(tf)
# processing  145000 th documents(tf)
# processing  146000 th documents(tf)
# processing  147000 th documents(tf)
# processing  148000 th documents(tf)
# processing  149000 th documents(tf)
# processing  150000 th documents(tf)
# processing  151000 th documents(tf)
# processing  152000 th documents(tf)
# processing  153000 th documents(tf)
# processing  154000 th documents(tf)
# processing  155000 th documents(tf)
# processing  156000 th documents(tf)
# processing  157000 th documents(tf)
# processing  158000 th documents(tf)
# processing  159000 th documents(tf)
# processing  160000 th documents(tf)
# processing  161000 th documents(tf)
# processing  162000 th documents(tf)
# processing  163000 th documents(tf)
# processing  164000 th documents(tf)
# processing  165000 th documents(tf)
# processing  166000 th documents(tf)
# processing  167000 th documents(tf)
# processing  168000 th documents(tf)
# processing  169000 th documents(tf)
# processing  170000 th documents(tf)
# processing  171000 th documents(tf)
# processing  172000 th documents(tf)
# processing  173000 th documents(tf)
# processing  174000 th documents(tf)
# processing  175000 th documents(tf)
# processing  176000 th documents(tf)
# processing  177000 th documents(tf)
# processing  178000 th documents(tf)
# processing  179000 th documents(tf)
# processing  180000 th documents(tf)
# processing  181000 th documents(tf)
# processing  182000 th documents(tf)
# processing  183000 th documents(tf)
# processing  184000 th documents(tf)
# processing  185000 th documents(tf)
# processing  186000 th documents(tf)
# processing  187000 th documents(tf)
# processing  188000 th documents(tf)
# processing  189000 th documents(tf)
# processing  190000 th documents(tf)
# processing  191000 th documents(tf)
# processing  192000 th documents(tf)
# processing  193000 th documents(tf)
# processing  194000 th documents(tf)
# processing  195000 th documents(tf)
# processing  196000 th documents(tf)
# processing  197000 th documents(tf)
# processing  198000 th documents(tf)
# processing  199000 th documents(tf)
# processing  200000 th documents(tf)
# processing  201000 th documents(tf)
# processing  202000 th documents(tf)
# processing  203000 th documents(tf)
# processing  204000 th documents(tf)
# processing  205000 th documents(tf)
# processing  206000 th documents(tf)
# processing  207000 th documents(tf)
# processing  208000 th documents(tf)
# processing  209000 th documents(tf)
# processing  210000 th documents(tf)
# processing  211000 th documents(tf)
# processing  212000 th documents(tf)
# processing  213000 th documents(tf)
# processing  214000 th documents(tf)
# processing  215000 th documents(tf)
# processing  216000 th documents(tf)
# processing  217000 th documents(tf)
# processing  218000 th documents(tf)
# processing  219000 th documents(tf)
# processing  220000 th documents(tf)
# processing  221000 th documents(tf)
# processing  222000 th documents(tf)
# processing  223000 th documents(tf)
# processing  224000 th documents(tf)
# processing  225000 th documents(tf)
# processing  226000 th documents(tf)
# processing  227000 th documents(tf)
# processing  228000 th documents(tf)
# processing  229000 th documents(tf)
# processing  230000 th documents(tf)
# processing  231000 th documents(tf)
# processing  232000 th documents(tf)
# processing  233000 th documents(tf)
# processing  234000 th documents(tf)
# processing  235000 th documents(tf)
# processing  236000 th documents(tf)
# processing  237000 th documents(tf)
# processing  238000 th documents(tf)
# processing  239000 th documents(tf)
# processing  240000 th documents(tf)
# processing  1000 th word(idf)
# processing  2000 th word(idf)
# processing  3000 th word(idf)
# processing  4000 th word(idf)
# processing  5000 th word(idf)
# processing  6000 th word(idf)
# processing  7000 th word(idf)
# processing  8000 th word(idf)
# processing  9000 th word(idf)
# processing  10000 th word(idf)
# processing  11000 th word(idf)
# processing  12000 th word(idf)
# processing  13000 th word(idf)
# processing  14000 th word(idf)
# processing  15000 th word(idf)
# processing  16000 th word(idf)
# processing  17000 th word(idf)
# processing  18000 th word(idf)
# processing  19000 th word(idf)
# processing  20000 th word(idf)
# processing  21000 th word(idf)
# processing  22000 th word(idf)
# processing  23000 th word(idf)
# processing  24000 th word(idf)
# processing  25000 th word(idf)
# processing  26000 th word(idf)
# processing  27000 th word(idf)

# %%
attr_title_tf, attr_title_idf, attr_title_length, attr_title_ave_length = utils.tfidf(df_all, 'attr_title')
df_all['attr_title_BM25_score'] = df_all.apply(lambda x: utils.BM25_score(x, attr_title_tf, attr_title_idf, attr_title_length, attr_title_ave_length), axis=1)
# Out:
# processing  1000 th documents(tf)
# processing  2000 th documents(tf)
# processing  3000 th documents(tf)
# processing  4000 th documents(tf)
# processing  5000 th documents(tf)
# processing  6000 th documents(tf)
# processing  7000 th documents(tf)
# processing  8000 th documents(tf)
# processing  9000 th documents(tf)
# processing  10000 th documents(tf)
# processing  11000 th documents(tf)
# processing  12000 th documents(tf)
# processing  13000 th documents(tf)
# processing  14000 th documents(tf)
# processing  15000 th documents(tf)
# processing  16000 th documents(tf)
# processing  17000 th documents(tf)
# processing  18000 th documents(tf)
# processing  19000 th documents(tf)
# processing  20000 th documents(tf)
# processing  21000 th documents(tf)
# processing  22000 th documents(tf)
# processing  23000 th documents(tf)
# processing  24000 th documents(tf)
# processing  25000 th documents(tf)
# processing  26000 th documents(tf)
# processing  27000 th documents(tf)
# processing  28000 th documents(tf)
# processing  29000 th documents(tf)
# processing  30000 th documents(tf)
# processing  31000 th documents(tf)
# processing  32000 th documents(tf)
# processing  33000 th documents(tf)
# processing  34000 th documents(tf)
# processing  35000 th documents(tf)
# processing  36000 th documents(tf)
# processing  37000 th documents(tf)
# processing  38000 th documents(tf)
# processing  39000 th documents(tf)
# processing  40000 th documents(tf)
# processing  41000 th documents(tf)
# processing  42000 th documents(tf)
# processing  43000 th documents(tf)
# processing  44000 th documents(tf)
# processing  45000 th documents(tf)
# processing  46000 th documents(tf)
# processing  47000 th documents(tf)
# processing  48000 th documents(tf)
# processing  49000 th documents(tf)
# processing  50000 th documents(tf)
# processing  51000 th documents(tf)
# processing  52000 th documents(tf)
# processing  53000 th documents(tf)
# processing  54000 th documents(tf)
# processing  55000 th documents(tf)
# processing  56000 th documents(tf)
# processing  57000 th documents(tf)
# processing  58000 th documents(tf)
# processing  59000 th documents(tf)
# processing  60000 th documents(tf)
# processing  61000 th documents(tf)
# processing  62000 th documents(tf)
# processing  63000 th documents(tf)
# processing  64000 th documents(tf)
# processing  65000 th documents(tf)
# processing  66000 th documents(tf)
# processing  67000 th documents(tf)
# processing  68000 th documents(tf)
# processing  69000 th documents(tf)
# processing  70000 th documents(tf)
# processing  71000 th documents(tf)
# processing  72000 th documents(tf)
# processing  73000 th documents(tf)
# processing  74000 th documents(tf)
# processing  75000 th documents(tf)
# processing  76000 th documents(tf)
# processing  77000 th documents(tf)
# processing  78000 th documents(tf)
# processing  79000 th documents(tf)
# processing  80000 th documents(tf)
# processing  81000 th documents(tf)
# processing  82000 th documents(tf)
# processing  83000 th documents(tf)
# processing  84000 th documents(tf)
# processing  85000 th documents(tf)
# processing  86000 th documents(tf)
# processing  87000 th documents(tf)
# processing  88000 th documents(tf)
# processing  89000 th documents(tf)
# processing  90000 th documents(tf)
# processing  91000 th documents(tf)
# processing  92000 th documents(tf)
# processing  93000 th documents(tf)
# processing  94000 th documents(tf)
# processing  95000 th documents(tf)
# processing  96000 th documents(tf)
# processing  97000 th documents(tf)
# processing  98000 th documents(tf)
# processing  99000 th documents(tf)
# processing  100000 th documents(tf)
# processing  101000 th documents(tf)
# processing  102000 th documents(tf)
# processing  103000 th documents(tf)
# processing  104000 th documents(tf)
# processing  105000 th documents(tf)
# processing  106000 th documents(tf)
# processing  107000 th documents(tf)
# processing  108000 th documents(tf)
# processing  109000 th documents(tf)
# processing  110000 th documents(tf)
# processing  111000 th documents(tf)
# processing  112000 th documents(tf)
# processing  113000 th documents(tf)
# processing  114000 th documents(tf)
# processing  115000 th documents(tf)
# processing  116000 th documents(tf)
# processing  117000 th documents(tf)
# processing  118000 th documents(tf)
# processing  119000 th documents(tf)
# processing  120000 th documents(tf)
# processing  121000 th documents(tf)
# processing  122000 th documents(tf)
# processing  123000 th documents(tf)
# processing  124000 th documents(tf)
# processing  125000 th documents(tf)
# processing  126000 th documents(tf)
# processing  127000 th documents(tf)
# processing  128000 th documents(tf)
# processing  129000 th documents(tf)
# processing  130000 th documents(tf)
# processing  131000 th documents(tf)
# processing  132000 th documents(tf)
# processing  133000 th documents(tf)
# processing  134000 th documents(tf)
# processing  135000 th documents(tf)
# processing  136000 th documents(tf)
# processing  137000 th documents(tf)
# processing  138000 th documents(tf)
# processing  139000 th documents(tf)
# processing  140000 th documents(tf)
# processing  141000 th documents(tf)
# processing  142000 th documents(tf)
# processing  143000 th documents(tf)
# processing  144000 th documents(tf)
# processing  145000 th documents(tf)
# processing  146000 th documents(tf)
# processing  147000 th documents(tf)
# processing  148000 th documents(tf)
# processing  149000 th documents(tf)
# processing  150000 th documents(tf)
# processing  151000 th documents(tf)
# processing  152000 th documents(tf)
# processing  153000 th documents(tf)
# processing  154000 th documents(tf)
# processing  155000 th documents(tf)
# processing  156000 th documents(tf)
# processing  157000 th documents(tf)
# processing  158000 th documents(tf)
# processing  159000 th documents(tf)
# processing  160000 th documents(tf)
# processing  161000 th documents(tf)
# processing  162000 th documents(tf)
# processing  163000 th documents(tf)
# processing  164000 th documents(tf)
# processing  165000 th documents(tf)
# processing  166000 th documents(tf)
# processing  167000 th documents(tf)
# processing  168000 th documents(tf)
# processing  169000 th documents(tf)
# processing  170000 th documents(tf)
# processing  171000 th documents(tf)
# processing  172000 th documents(tf)
# processing  173000 th documents(tf)
# processing  174000 th documents(tf)
# processing  175000 th documents(tf)
# processing  176000 th documents(tf)
# processing  177000 th documents(tf)
# processing  178000 th documents(tf)
# processing  179000 th documents(tf)
# processing  180000 th documents(tf)
# processing  181000 th documents(tf)
# processing  182000 th documents(tf)
# processing  183000 th documents(tf)
# processing  184000 th documents(tf)
# processing  185000 th documents(tf)
# processing  186000 th documents(tf)
# processing  187000 th documents(tf)
# processing  188000 th documents(tf)
# processing  189000 th documents(tf)
# processing  190000 th documents(tf)
# processing  191000 th documents(tf)
# processing  192000 th documents(tf)
# processing  193000 th documents(tf)
# processing  194000 th documents(tf)
# processing  195000 th documents(tf)
# processing  196000 th documents(tf)
# processing  197000 th documents(tf)
# processing  198000 th documents(tf)
# processing  199000 th documents(tf)
# processing  200000 th documents(tf)
# processing  201000 th documents(tf)
# processing  202000 th documents(tf)
# processing  203000 th documents(tf)
# processing  204000 th documents(tf)
# processing  205000 th documents(tf)
# processing  206000 th documents(tf)
# processing  207000 th documents(tf)
# processing  208000 th documents(tf)
# processing  209000 th documents(tf)
# processing  210000 th documents(tf)
# processing  211000 th documents(tf)
# processing  212000 th documents(tf)
# processing  213000 th documents(tf)
# processing  214000 th documents(tf)
# processing  215000 th documents(tf)
# processing  216000 th documents(tf)
# processing  217000 th documents(tf)
# processing  218000 th documents(tf)
# processing  219000 th documents(tf)
# processing  220000 th documents(tf)
# processing  221000 th documents(tf)
# processing  222000 th documents(tf)
# processing  223000 th documents(tf)
# processing  224000 th documents(tf)
# processing  225000 th documents(tf)
# processing  226000 th documents(tf)
# processing  227000 th documents(tf)
# processing  228000 th documents(tf)
# processing  229000 th documents(tf)
# processing  230000 th documents(tf)
# processing  231000 th documents(tf)
# processing  232000 th documents(tf)
# processing  233000 th documents(tf)
# processing  234000 th documents(tf)
# processing  235000 th documents(tf)
# processing  236000 th documents(tf)
# processing  237000 th documents(tf)
# processing  238000 th documents(tf)
# processing  239000 th documents(tf)
# processing  240000 th documents(tf)
# processing  1000 th word(idf)
# processing  2000 th word(idf)

# %%
brand_tf, brand_idf, brand_length, brand_ave_length = utils.tfidf(df_all, 'brand')
df_all['brand_BM25_score'] = df_all.apply(lambda x: utils.BM25_score(x, brand_tf, brand_idf, brand_length, brand_ave_length), axis=1)
# Out:
# processing  1000 th documents(tf)
# processing  2000 th documents(tf)
# processing  3000 th documents(tf)
# processing  4000 th documents(tf)
# processing  5000 th documents(tf)
# processing  6000 th documents(tf)
# processing  7000 th documents(tf)
# processing  8000 th documents(tf)
# processing  9000 th documents(tf)
# processing  10000 th documents(tf)
# processing  11000 th documents(tf)
# processing  12000 th documents(tf)
# processing  13000 th documents(tf)
# processing  14000 th documents(tf)
# processing  15000 th documents(tf)
# processing  16000 th documents(tf)
# processing  17000 th documents(tf)
# processing  18000 th documents(tf)
# processing  19000 th documents(tf)
# processing  20000 th documents(tf)
# processing  21000 th documents(tf)
# processing  22000 th documents(tf)
# processing  23000 th documents(tf)
# processing  24000 th documents(tf)
# processing  25000 th documents(tf)
# processing  26000 th documents(tf)
# processing  27000 th documents(tf)
# processing  28000 th documents(tf)
# processing  29000 th documents(tf)
# processing  30000 th documents(tf)
# processing  31000 th documents(tf)
# processing  32000 th documents(tf)
# processing  33000 th documents(tf)
# processing  34000 th documents(tf)
# processing  35000 th documents(tf)
# processing  36000 th documents(tf)
# processing  37000 th documents(tf)
# processing  38000 th documents(tf)
# processing  39000 th documents(tf)
# processing  40000 th documents(tf)
# processing  41000 th documents(tf)
# processing  42000 th documents(tf)
# processing  43000 th documents(tf)
# processing  44000 th documents(tf)
# processing  45000 th documents(tf)
# processing  46000 th documents(tf)
# processing  47000 th documents(tf)
# processing  48000 th documents(tf)
# processing  49000 th documents(tf)
# processing  50000 th documents(tf)
# processing  51000 th documents(tf)
# processing  52000 th documents(tf)
# processing  53000 th documents(tf)
# processing  54000 th documents(tf)
# processing  55000 th documents(tf)
# processing  56000 th documents(tf)
# processing  57000 th documents(tf)
# processing  58000 th documents(tf)
# processing  59000 th documents(tf)
# processing  60000 th documents(tf)
# processing  61000 th documents(tf)
# processing  62000 th documents(tf)
# processing  63000 th documents(tf)
# processing  64000 th documents(tf)
# processing  65000 th documents(tf)
# processing  66000 th documents(tf)
# processing  67000 th documents(tf)
# processing  68000 th documents(tf)
# processing  69000 th documents(tf)
# processing  70000 th documents(tf)
# processing  71000 th documents(tf)
# processing  72000 th documents(tf)
# processing  73000 th documents(tf)
# processing  74000 th documents(tf)
# processing  75000 th documents(tf)
# processing  76000 th documents(tf)
# processing  77000 th documents(tf)
# processing  78000 th documents(tf)
# processing  79000 th documents(tf)
# processing  80000 th documents(tf)
# processing  81000 th documents(tf)
# processing  82000 th documents(tf)
# processing  83000 th documents(tf)
# processing  84000 th documents(tf)
# processing  85000 th documents(tf)
# processing  86000 th documents(tf)
# processing  87000 th documents(tf)
# processing  88000 th documents(tf)
# processing  89000 th documents(tf)
# processing  90000 th documents(tf)
# processing  91000 th documents(tf)
# processing  92000 th documents(tf)
# processing  93000 th documents(tf)
# processing  94000 th documents(tf)
# processing  95000 th documents(tf)
# processing  96000 th documents(tf)
# processing  97000 th documents(tf)
# processing  98000 th documents(tf)
# processing  99000 th documents(tf)
# processing  100000 th documents(tf)
# processing  101000 th documents(tf)
# processing  102000 th documents(tf)
# processing  103000 th documents(tf)
# processing  104000 th documents(tf)
# processing  105000 th documents(tf)
# processing  106000 th documents(tf)
# processing  107000 th documents(tf)
# processing  108000 th documents(tf)
# processing  109000 th documents(tf)
# processing  110000 th documents(tf)
# processing  111000 th documents(tf)
# processing  112000 th documents(tf)
# processing  113000 th documents(tf)
# processing  114000 th documents(tf)
# processing  115000 th documents(tf)
# processing  116000 th documents(tf)
# processing  117000 th documents(tf)
# processing  118000 th documents(tf)
# processing  119000 th documents(tf)
# processing  120000 th documents(tf)
# processing  121000 th documents(tf)
# processing  122000 th documents(tf)
# processing  123000 th documents(tf)
# processing  124000 th documents(tf)
# processing  125000 th documents(tf)
# processing  126000 th documents(tf)
# processing  127000 th documents(tf)
# processing  128000 th documents(tf)
# processing  129000 th documents(tf)
# processing  130000 th documents(tf)
# processing  131000 th documents(tf)
# processing  132000 th documents(tf)
# processing  133000 th documents(tf)
# processing  134000 th documents(tf)
# processing  135000 th documents(tf)
# processing  136000 th documents(tf)
# processing  137000 th documents(tf)
# processing  138000 th documents(tf)
# processing  139000 th documents(tf)
# processing  140000 th documents(tf)
# processing  141000 th documents(tf)
# processing  142000 th documents(tf)
# processing  143000 th documents(tf)
# processing  144000 th documents(tf)
# processing  145000 th documents(tf)
# processing  146000 th documents(tf)
# processing  147000 th documents(tf)
# processing  148000 th documents(tf)
# processing  149000 th documents(tf)
# processing  150000 th documents(tf)
# processing  151000 th documents(tf)
# processing  152000 th documents(tf)
# processing  153000 th documents(tf)
# processing  154000 th documents(tf)
# processing  155000 th documents(tf)
# processing  156000 th documents(tf)
# processing  157000 th documents(tf)
# processing  158000 th documents(tf)
# processing  159000 th documents(tf)
# processing  160000 th documents(tf)
# processing  161000 th documents(tf)
# processing  162000 th documents(tf)
# processing  163000 th documents(tf)
# processing  164000 th documents(tf)
# processing  165000 th documents(tf)
# processing  166000 th documents(tf)
# processing  167000 th documents(tf)
# processing  168000 th documents(tf)
# processing  169000 th documents(tf)
# processing  170000 th documents(tf)
# processing  171000 th documents(tf)
# processing  172000 th documents(tf)
# processing  173000 th documents(tf)
# processing  174000 th documents(tf)
# processing  175000 th documents(tf)
# processing  176000 th documents(tf)
# processing  177000 th documents(tf)
# processing  178000 th documents(tf)
# processing  179000 th documents(tf)
# processing  180000 th documents(tf)
# processing  181000 th documents(tf)
# processing  182000 th documents(tf)
# processing  183000 th documents(tf)
# processing  184000 th documents(tf)
# processing  185000 th documents(tf)
# processing  186000 th documents(tf)
# processing  187000 th documents(tf)
# processing  188000 th documents(tf)
# processing  189000 th documents(tf)
# processing  190000 th documents(tf)
# processing  191000 th documents(tf)
# processing  192000 th documents(tf)
# processing  193000 th documents(tf)
# processing  194000 th documents(tf)
# processing  195000 th documents(tf)
# processing  196000 th documents(tf)
# processing  197000 th documents(tf)
# processing  198000 th documents(tf)
# processing  199000 th documents(tf)
# processing  200000 th documents(tf)
# processing  201000 th documents(tf)
# processing  202000 th documents(tf)
# processing  203000 th documents(tf)
# processing  204000 th documents(tf)
# processing  205000 th documents(tf)
# processing  206000 th documents(tf)
# processing  207000 th documents(tf)
# processing  208000 th documents(tf)
# processing  209000 th documents(tf)
# processing  210000 th documents(tf)
# processing  211000 th documents(tf)
# processing  212000 th documents(tf)
# processing  213000 th documents(tf)
# processing  214000 th documents(tf)
# processing  215000 th documents(tf)
# processing  216000 th documents(tf)
# processing  217000 th documents(tf)
# processing  218000 th documents(tf)
# processing  219000 th documents(tf)
# processing  220000 th documents(tf)
# processing  221000 th documents(tf)
# processing  222000 th documents(tf)
# processing  223000 th documents(tf)
# processing  224000 th documents(tf)
# processing  225000 th documents(tf)
# processing  226000 th documents(tf)
# processing  227000 th documents(tf)
# processing  228000 th documents(tf)
# processing  229000 th documents(tf)
# processing  230000 th documents(tf)
# processing  231000 th documents(tf)
# processing  232000 th documents(tf)
# processing  233000 th documents(tf)
# processing  234000 th documents(tf)
# processing  235000 th documents(tf)
# processing  236000 th documents(tf)
# processing  237000 th documents(tf)
# processing  238000 th documents(tf)
# processing  239000 th documents(tf)
# processing  240000 th documents(tf)
# processing  1000 th word(idf)
# processing  2000 th word(idf)
# processing  3000 th word(idf)
# processing  4000 th word(idf)

# %%
df_brand = pd.unique(df_all.brand.ravel())
d = {}
i = 1000
for s in df_brand:
    d[s] = i
    i += 3
df_all['brand_feature'] = df_all['brand'].map(lambda x: d[x])
df_all['search_term_feature'] = df_all['search_term'].map(lambda x: len(x))

# %%
df_all.to_csv("C:/Users/JayZheng/Documents/Data Science/data mining/home-depot/data/df_all.csv",index = False)

# %%
X_train.drop(X_train.columns[[0,1,2,3,4,5,6,7,8]],axis=1,inplace = True)
# Out:
# C:\Users\JayZheng\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
model = RandomForestRegressor(n_estimators=500, n_jobs=-1, random_state=42, verbose=1) #first try parameters

# %%
model.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   44.7s finished
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=500, n_jobs=-1, oob_score=False, random_state=42,
#            verbose=1, warm_start=False)

# %%
df_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7a40b0e416bb> in <module>()
# ----> 1 df_train
#
# NameError: name 'df_train' is not defined

# %%
len(y_train)
# Out:
# 74067

# %%
X_test.drop(X_test[[0,1,2,3,4,5,6,7,8]],axis = 1,inplace=True)
# Out:
# C:\Users\JayZheng\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
predict = model.predict(X_test)
# Out:
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.8s finished
